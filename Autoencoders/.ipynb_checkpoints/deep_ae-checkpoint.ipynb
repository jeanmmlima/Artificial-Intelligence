# %% [markdown]
# ### Deep Autoencoder with Keras

# %%
from keras.datasets import mnist
from keras.layers import Input, Dense
from keras.models import Model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#mnist

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255
X_train = X_train.reshape(len(X_train), np.prod(X_train.shape[1:]))
X_test = X_test.reshape(len(X_test), np.prod(X_test.shape[1:]))
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ![deep_autoencoder](https://miro.medium.com/max/700/1*EQU7F2dZ6p7_qiA_OS6qQg.png)

# %%
#model

#We need to take the input image of dimension 784 and convert it to keras tensors.
input_img= Input(shape=(784,))

#To build the autoencoder we will have to first encode the input image and add 
#different encoded and decoded layer to build the deep autoencoder as shown below.

encoded = Dense(units=128, activation='relu')(input_img)
encoded = Dense(units=64, activation='relu')(encoded)
encoded = Dense(units=32, activation='relu')(encoded)
decoded = Dense(units=64, activation='relu')(encoded)
decoded = Dense(units=128, activation='relu')(decoded)
decoded = Dense(units=784, activation='sigmoid')(decoded)

#For all the hidden layers for the encoder and decoder we use relu activation function for non-linearity.

autoencoder=Model(input_img, decoded)

#We can extract the encoder which takes input image as the input and 
#the output of encoder is the encoded image of dimension 32
encoder = Model(input_img, encoded)

autoencoder.summary()
encoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_5 (Dense)              (None, 784)               101136
# =================================================================
# Total params: 222,384
# Trainable params: 222,384
# Non-trainable params: 0
# _________________________________________________________________
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# =================================================================
# Total params: 110,816
# Trainable params: 110,816
# Non-trainable params: 0
# _________________________________________________________________

# %%
#We compile the autoencoder model with adam optimizer.
#As pixels have a value of 0 0r 1 we use binary_crossentropy as the loss function
#We use accuracy as the metrics used for the performance of the model.

autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#We finally train the autoencoder using the training data with 50 epochs and batch size of 256.
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))

encoded_imgs = encoder.predict(X_test)
predicted = autoencoder.predict(X_test)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2448 - accuracy: 0.0095 - val_loss: 0.1686 - val_accuracy: 0.0101
# Epoch 2/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1517 - accuracy: 0.0125 - val_loss: 0.1371 - val_accuracy: 0.0098
# Epoch 3/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1325 - accuracy: 0.0093 - val_loss: 0.1259 - val_accuracy: 0.0097
# Epoch 4/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1243 - accuracy: 0.0109 - val_loss: 0.1196 - val_accuracy: 0.0133
# Epoch 5/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1187 - accuracy: 0.0125 - val_loss: 0.1148 - val_accuracy: 0.0141
# Epoch 6/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1140 - accuracy: 0.0122 - val_loss: 0.1114 - val_accuracy: 0.0137
# Epoch 7/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1106 - accuracy: 0.0124 - val_loss: 0.1081 - val_accuracy: 0.0134
# Epoch 8/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1081 - accuracy: 0.0128 - val_loss: 0.1059 - val_accuracy: 0.0130
# Epoch 9/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1059 - accuracy: 0.0126 - val_loss: 0.1041 - val_accuracy: 0.0125
# Epoch 10/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1041 - accuracy: 0.0126 - val_loss: 0.1028 - val_accuracy: 0.0125
# Epoch 11/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1028 - accuracy: 0.0122 - val_loss: 0.1013 - val_accuracy: 0.0141
# Epoch 12/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1016 - accuracy: 0.0125 - val_loss: 0.1005 - val_accuracy: 0.0118
# Epoch 13/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1005 - accuracy: 0.0124 - val_loss: 0.0991 - val_accuracy: 0.0097
# Epoch 14/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0996 - accuracy: 0.0125 - val_loss: 0.0981 - val_accuracy: 0.0100
# Epoch 15/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0987 - accuracy: 0.0130 - val_loss: 0.0970 - val_accuracy: 0.0128
# Epoch 16/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0977 - accuracy: 0.0131 - val_loss: 0.0967 - val_accuracy: 0.0136
# Epoch 17/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0970 - accuracy: 0.0136 - val_loss: 0.0956 - val_accuracy: 0.0156
# Epoch 18/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0961 - accuracy: 0.0140 - val_loss: 0.0952 - val_accuracy: 0.0135
# Epoch 19/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0954 - accuracy: 0.0141 - val_loss: 0.0944 - val_accuracy: 0.0126
# Epoch 20/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0946 - accuracy: 0.0138 - val_loss: 0.0937 - val_accuracy: 0.0101
# Epoch 21/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0939 - accuracy: 0.0134 - val_loss: 0.0928 - val_accuracy: 0.0146
# Epoch 22/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0932 - accuracy: 0.0136 - val_loss: 0.0921 - val_accuracy: 0.0124
# Epoch 23/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0925 - accuracy: 0.0132 - val_loss: 0.0916 - val_accuracy: 0.0136
# Epoch 24/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0920 - accuracy: 0.0137 - val_loss: 0.0912 - val_accuracy: 0.0122
# Epoch 25/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0915 - accuracy: 0.0135 - val_loss: 0.0904 - val_accuracy: 0.0135
# Epoch 26/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0910 - accuracy: 0.0138 - val_loss: 0.0902 - val_accuracy: 0.0130
# Epoch 27/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0906 - accuracy: 0.0131 - val_loss: 0.0898 - val_accuracy: 0.0123
# Epoch 28/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0902 - accuracy: 0.0133 - val_loss: 0.0894 - val_accuracy: 0.0118
# Epoch 29/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0898 - accuracy: 0.0138 - val_loss: 0.0890 - val_accuracy: 0.0136
# Epoch 30/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0895 - accuracy: 0.0133 - val_loss: 0.0888 - val_accuracy: 0.0131
# Epoch 31/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0892 - accuracy: 0.0135 - val_loss: 0.0886 - val_accuracy: 0.0136
# Epoch 32/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0889 - accuracy: 0.0133 - val_loss: 0.0883 - val_accuracy: 0.0121
# Epoch 33/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0886 - accuracy: 0.0134 - val_loss: 0.0878 - val_accuracy: 0.0132
# Epoch 34/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0884 - accuracy: 0.0132 - val_loss: 0.0879 - val_accuracy: 0.0134
# Epoch 35/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0881 - accuracy: 0.0136 - val_loss: 0.0876 - val_accuracy: 0.0126
# Epoch 36/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0879 - accuracy: 0.0133 - val_loss: 0.0874 - val_accuracy: 0.0131
# Epoch 37/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0877 - accuracy: 0.0136 - val_loss: 0.0872 - val_accuracy: 0.0144
# Epoch 38/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0875 - accuracy: 0.0134 - val_loss: 0.0870 - val_accuracy: 0.0130
# Epoch 39/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0873 - accuracy: 0.0138 - val_loss: 0.0866 - val_accuracy: 0.0133
# Epoch 40/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0871 - accuracy: 0.0138 - val_loss: 0.0866 - val_accuracy: 0.0148
# Epoch 41/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0870 - accuracy: 0.0139 - val_loss: 0.0866 - val_accuracy: 0.0117
# Epoch 42/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0868 - accuracy: 0.0133 - val_loss: 0.0862 - val_accuracy: 0.0120
# Epoch 43/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0867 - accuracy: 0.0137 - val_loss: 0.0861 - val_accuracy: 0.0132
# Epoch 44/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0866 - accuracy: 0.0138 - val_loss: 0.0860 - val_accuracy: 0.0132
# Epoch 45/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0865 - accuracy: 0.0143 - val_loss: 0.0861 - val_accuracy: 0.0142
# Epoch 46/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0863 - accuracy: 0.0139 - val_loss: 0.0861 - val_accuracy: 0.0131
# Epoch 47/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0862 - accuracy: 0.0136 - val_loss: 0.0859 - val_accuracy: 0.0143
# Epoch 48/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0861 - accuracy: 0.0136 - val_loss: 0.0856 - val_accuracy: 0.0125
# Epoch 49/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0860 - accuracy: 0.0140 - val_loss: 0.0856 - val_accuracy: 0.0130
# Epoch 50/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0859 - accuracy: 0.0142 - val_loss: 0.0856 - val_accuracy: 0.0111

# %%
plt.figure(figsize=(40, 4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display encoded images
    ax = plt.subplot(3, 20, i + 1 + 20)
    plt.imshow(encoded_imgs[i].reshape(8,4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  
    
plt.show()

# %% [markdown]
# ### DENOISING AUTOENCODERS

# %%
#loading only images and not their labels
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

X_train = X_train.reshape(len(X_train), np.prod(X_train.shape[1:]))
X_test = X_test.reshape(len(X_test), np.prod(X_test.shape[1:]))
X_train_noisy = X_train + np.random.normal(loc=0.0, scale=0.5, size=X_train.shape)
X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = X_test + np.random.normal(loc=0.0, scale=0.5, size=X_test.shape)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)
print(X_train_noisy.shape)
print(X_test_noisy.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
#Input image
input_img= Input(shape=(784,))
# encoded and decoded layer for the autoencoder
encoded = Dense(units=128, activation='relu')(input_img)
encoded = Dense(units=64, activation='relu')(encoded)
encoded = Dense(units=32, activation='relu')(encoded)
decoded = Dense(units=64, activation='relu')(encoded)
decoded = Dense(units=128, activation='relu')(decoded)
decoded = Dense(units=784, activation='sigmoid')(decoded)
# Building autoencoder
autoencoder=Model(input_img, decoded)
#extracting encoder
encoder = Model(input_img, encoded)
# compiling the autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])
# Fitting the noise trained data to the autoencoder 
autoencoder.fit(X_train_noisy, X_train_noisy,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test_noisy, X_test_noisy))
# reconstructing the image from autoencoder and encoder
encoded_imgs = encoder.predict(X_test_noisy)
predicted = autoencoder.predict(X_test_noisy)
# plotting the noised image, encoded image and the reconstructed image
plt.figure(figsize=(40, 4))
for i in range(10):
# display original images
    
    ax = plt.subplot(4, 20, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
# display noised images
    ax = plt.subplot(4, 20, i + 1+20)
    plt.imshow(X_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# display encoded images    
    ax = plt.subplot(4, 20, 2*20+i + 1 )
    plt.imshow(encoded_imgs[i].reshape(8,4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# display reconstruction images
    ax = plt.subplot(4, 20, 3*20 +i+ 1)
    plt.imshow(predicted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    
plt.show()
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6929 - accuracy: 0.0024 - val_loss: 0.6929 - val_accuracy: 0.0022
# Epoch 2/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6929 - accuracy: 0.0024 - val_loss: 0.6928 - val_accuracy: 0.0022
# Epoch 3/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6928 - accuracy: 0.0025 - val_loss: 0.6928 - val_accuracy: 0.0022
# Epoch 4/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6928 - accuracy: 0.0025 - val_loss: 0.6928 - val_accuracy: 0.0022
# Epoch 5/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6928 - accuracy: 0.0025 - val_loss: 0.6927 - val_accuracy: 0.0022
# Epoch 6/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6927 - accuracy: 0.0025 - val_loss: 0.6927 - val_accuracy: 0.0020
# Epoch 7/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6927 - accuracy: 0.0025 - val_loss: 0.6927 - val_accuracy: 0.0020
# Epoch 8/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6927 - accuracy: 0.0025 - val_loss: 0.6926 - val_accuracy: 0.0020
# Epoch 9/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6926 - accuracy: 0.0025 - val_loss: 0.6926 - val_accuracy: 0.0018
# Epoch 10/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6926 - accuracy: 0.0025 - val_loss: 0.6926 - val_accuracy: 0.0019
# Epoch 11/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6926 - accuracy: 0.0025 - val_loss: 0.6925 - val_accuracy: 0.0019
# Epoch 12/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6925 - accuracy: 0.0025 - val_loss: 0.6925 - val_accuracy: 0.0019
# Epoch 13/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6925 - accuracy: 0.0025 - val_loss: 0.6925 - val_accuracy: 0.0019
# Epoch 14/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6924 - accuracy: 0.0024 - val_loss: 0.6924 - val_accuracy: 0.0019
# Epoch 15/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6924 - accuracy: 0.0025 - val_loss: 0.6924 - val_accuracy: 0.0019
# Epoch 16/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6924 - accuracy: 0.0024 - val_loss: 0.6924 - val_accuracy: 0.0019
# Epoch 17/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.6923 - accuracy: 0.0024 - val_loss: 0.6923 - val_accuracy: 0.0019
# Epoch 18/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6923 - accuracy: 0.0024 - val_loss: 0.6923 - val_accuracy: 0.0019
# Epoch 19/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6923 - accuracy: 0.0023 - val_loss: 0.6922 - val_accuracy: 0.0019
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6922 - accuracy: 0.0023 - val_loss: 0.6922 - val_accuracy: 0.0019
# Epoch 21/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6922 - accuracy: 0.0023 - val_loss: 0.6922 - val_accuracy: 0.0019
# Epoch 22/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6922 - accuracy: 0.0023 - val_loss: 0.6921 - val_accuracy: 0.0019
# Epoch 23/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6921 - accuracy: 0.0023 - val_loss: 0.6921 - val_accuracy: 0.0019
# Epoch 24/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6921 - accuracy: 0.0023 - val_loss: 0.6921 - val_accuracy: 0.0018
# Epoch 25/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6920 - accuracy: 0.0023 - val_loss: 0.6920 - val_accuracy: 0.0018
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6920 - accuracy: 0.0023 - val_loss: 0.6920 - val_accuracy: 0.0018
# Epoch 27/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6920 - accuracy: 0.0023 - val_loss: 0.6919 - val_accuracy: 0.0018
# Epoch 28/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6919 - accuracy: 0.0022 - val_loss: 0.6919 - val_accuracy: 0.0017
# Epoch 29/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6919 - accuracy: 0.0022 - val_loss: 0.6919 - val_accuracy: 0.0016
# Epoch 30/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6919 - accuracy: 0.0022 - val_loss: 0.6918 - val_accuracy: 0.0016
# Epoch 31/100
# 235/235 [==============================] - 6s 24ms/step - loss: 0.6918 - accuracy: 0.0021 - val_loss: 0.6918 - val_accuracy: 0.0016
# Epoch 32/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6918 - accuracy: 0.0021 - val_loss: 0.6918 - val_accuracy: 0.0015
# Epoch 33/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6917 - accuracy: 0.0021 - val_loss: 0.6917 - val_accuracy: 0.0015
# Epoch 34/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6917 - accuracy: 0.0020 - val_loss: 0.6917 - val_accuracy: 0.0015
# Epoch 35/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6917 - accuracy: 0.0021 - val_loss: 0.6916 - val_accuracy: 0.0015
# Epoch 36/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6916 - accuracy: 0.0020 - val_loss: 0.6916 - val_accuracy: 0.0014
# Epoch 37/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6916 - accuracy: 0.0020 - val_loss: 0.6915 - val_accuracy: 0.0013
# Epoch 38/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6915 - accuracy: 0.0019 - val_loss: 0.6915 - val_accuracy: 0.0013
# Epoch 39/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6915 - accuracy: 0.0018 - val_loss: 0.6915 - val_accuracy: 0.0013
# Epoch 40/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6915 - accuracy: 0.0018 - val_loss: 0.6914 - val_accuracy: 0.0013
# Epoch 41/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6914 - accuracy: 0.0017 - val_loss: 0.6914 - val_accuracy: 0.0013
# Epoch 42/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6914 - accuracy: 0.0017 - val_loss: 0.6913 - val_accuracy: 0.0013
# Epoch 43/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6913 - accuracy: 0.0017 - val_loss: 0.6913 - val_accuracy: 0.0013
# Epoch 44/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6913 - accuracy: 0.0016 - val_loss: 0.6912 - val_accuracy: 0.0013
# Epoch 45/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6912 - accuracy: 0.0016 - val_loss: 0.6912 - val_accuracy: 0.0012
# Epoch 46/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6912 - accuracy: 0.0016 - val_loss: 0.6912 - val_accuracy: 0.0011
# Epoch 47/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6911 - accuracy: 0.0015 - val_loss: 0.6911 - val_accuracy: 0.0011
# Epoch 48/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6911 - accuracy: 0.0015 - val_loss: 0.6911 - val_accuracy: 0.0011
# Epoch 49/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6910 - accuracy: 0.0015 - val_loss: 0.6910 - val_accuracy: 0.0011
# Epoch 50/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6910 - accuracy: 0.0015 - val_loss: 0.6910 - val_accuracy: 0.0011
# Epoch 51/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6910 - accuracy: 0.0015 - val_loss: 0.6909 - val_accuracy: 0.0011
# Epoch 52/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6909 - accuracy: 0.0014 - val_loss: 0.6909 - val_accuracy: 0.0011
# Epoch 53/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6909 - accuracy: 0.0014 - val_loss: 0.6908 - val_accuracy: 0.0011
# Epoch 54/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6908 - accuracy: 0.0014 - val_loss: 0.6908 - val_accuracy: 0.0010
# Epoch 55/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6908 - accuracy: 0.0014 - val_loss: 0.6907 - val_accuracy: 0.0010
# Epoch 56/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6907 - accuracy: 0.0014 - val_loss: 0.6907 - val_accuracy: 8.0000e-04
# Epoch 57/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6906 - accuracy: 0.0013 - val_loss: 0.6906 - val_accuracy: 8.0000e-04
# Epoch 58/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6906 - accuracy: 0.0012 - val_loss: 0.6906 - val_accuracy: 8.0000e-04
# Epoch 59/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6905 - accuracy: 0.0012 - val_loss: 0.6905 - val_accuracy: 7.0000e-04
# Epoch 60/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6905 - accuracy: 0.0011 - val_loss: 0.6904 - val_accuracy: 7.0000e-04
# Epoch 61/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6904 - accuracy: 0.0011 - val_loss: 0.6904 - val_accuracy: 7.0000e-04
# Epoch 62/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6904 - accuracy: 0.0011 - val_loss: 0.6903 - val_accuracy: 6.0000e-04
# Epoch 63/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6903 - accuracy: 0.0010 - val_loss: 0.6903 - val_accuracy: 6.0000e-04
# Epoch 64/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6903 - accuracy: 0.0010 - val_loss: 0.6902 - val_accuracy: 6.0000e-04
# Epoch 65/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6902 - accuracy: 9.8333e-04 - val_loss: 0.6902 - val_accuracy: 5.0000e-04
# Epoch 66/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6901 - accuracy: 8.8333e-04 - val_loss: 0.6901 - val_accuracy: 5.0000e-04
# Epoch 67/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6901 - accuracy: 8.6667e-04 - val_loss: 0.6900 - val_accuracy: 5.0000e-04
# Epoch 68/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6900 - accuracy: 8.5000e-04 - val_loss: 0.6900 - val_accuracy: 5.0000e-04
# Epoch 69/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6900 - accuracy: 8.0000e-04 - val_loss: 0.6899 - val_accuracy: 5.0000e-04
# Epoch 70/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6899 - accuracy: 8.0000e-04 - val_loss: 0.6898 - val_accuracy: 6.0000e-04
# Epoch 71/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6898 - accuracy: 7.8333e-04 - val_loss: 0.6898 - val_accuracy: 6.0000e-04
# Epoch 72/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6898 - accuracy: 7.3333e-04 - val_loss: 0.6897 - val_accuracy: 6.0000e-04
# Epoch 73/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6897 - accuracy: 7.0000e-04 - val_loss: 0.6896 - val_accuracy: 6.0000e-04
# Epoch 74/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6896 - accuracy: 6.6667e-04 - val_loss: 0.6896 - val_accuracy: 6.0000e-04
# Epoch 75/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6895 - accuracy: 6.5000e-04 - val_loss: 0.6895 - val_accuracy: 6.0000e-04
# Epoch 76/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6895 - accuracy: 6.3333e-04 - val_loss: 0.6894 - val_accuracy: 5.0000e-04
# Epoch 77/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6894 - accuracy: 5.8333e-04 - val_loss: 0.6893 - val_accuracy: 4.0000e-04
# Epoch 78/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6893 - accuracy: 5.3333e-04 - val_loss: 0.6893 - val_accuracy: 4.0000e-04
# Epoch 79/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6892 - accuracy: 5.0000e-04 - val_loss: 0.6892 - val_accuracy: 4.0000e-04
# Epoch 80/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6892 - accuracy: 5.0000e-04 - val_loss: 0.6891 - val_accuracy: 3.0000e-04
# Epoch 81/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6891 - accuracy: 4.5000e-04 - val_loss: 0.6890 - val_accuracy: 3.0000e-04
# Epoch 82/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6890 - accuracy: 4.1667e-04 - val_loss: 0.6889 - val_accuracy: 2.0000e-04
# Epoch 83/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6889 - accuracy: 4.0000e-04 - val_loss: 0.6889 - val_accuracy: 2.0000e-04
# Epoch 84/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6888 - accuracy: 4.0000e-04 - val_loss: 0.6888 - val_accuracy: 2.0000e-04
# Epoch 85/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6888 - accuracy: 4.0000e-04 - val_loss: 0.6887 - val_accuracy: 2.0000e-04
# Epoch 86/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6887 - accuracy: 3.8333e-04 - val_loss: 0.6886 - val_accuracy: 2.0000e-04
# Epoch 87/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6886 - accuracy: 3.6667e-04 - val_loss: 0.6885 - val_accuracy: 2.0000e-04
# Epoch 88/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6885 - accuracy: 3.6667e-04 - val_loss: 0.6884 - val_accuracy: 2.0000e-04
# Epoch 89/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6884 - accuracy: 3.3333e-04 - val_loss: 0.6883 - val_accuracy: 2.0000e-04
# Epoch 90/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6883 - accuracy: 3.1667e-04 - val_loss: 0.6882 - val_accuracy: 2.0000e-04
# Epoch 91/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6882 - accuracy: 3.0000e-04 - val_loss: 0.6881 - val_accuracy: 2.0000e-04
# Epoch 92/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6881 - accuracy: 2.5000e-04 - val_loss: 0.6880 - val_accuracy: 2.0000e-04
# Epoch 93/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6880 - accuracy: 2.5000e-04 - val_loss: 0.6879 - val_accuracy: 2.0000e-04
# Epoch 94/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6879 - accuracy: 2.3333e-04 - val_loss: 0.6878 - val_accuracy: 2.0000e-04
# Epoch 95/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6878 - accuracy: 2.1667e-04 - val_loss: 0.6877 - val_accuracy: 2.0000e-04
# Epoch 96/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6876 - accuracy: 1.8333e-04 - val_loss: 0.6876 - val_accuracy: 1.0000e-04
# Epoch 97/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6875 - accuracy: 1.3333e-04 - val_loss: 0.6874 - val_accuracy: 1.0000e-04
# Epoch 98/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6874 - accuracy: 1.3333e-04 - val_loss: 0.6873 - val_accuracy: 1.0000e-04
# Epoch 99/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6873 - accuracy: 1.3333e-04 - val_loss: 0.6872 - val_accuracy: 1.0000e-04
# Epoch 100/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6872 - accuracy: 1.3333e-04 - val_loss: 0.6871 - val_accuracy: 1.0000e-04
